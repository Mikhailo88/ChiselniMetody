# %% [markdown]
# <a href="https://colab.research.google.com/github/Mikhailo88/ChiselniMetody/blob/main/%D0%9B%D0%B15_%D0%9E%D0%BB%D1%8C%D1%85%D0%BE%D0%B2%D0%B5%D0%BD%D0%BA%D0%BE_%D0%A4%D0%86%D0%A2_2_8_%D0%92%D0%B0%D1%80_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy

# %%
import numpy as np
import matplotlib.pyplot as plt

# Область значень для x та y
x_min, x_max = -1, 3
y_min, y_max = -4, 4
step = 0.01

# Створюємо масиви значень x та y
x, y = np.meshgrid(np.arange(x_min, x_max, step), np.arange(y_min, y_max, step))

# Рівняння системи
eq1 = np.sin(x + 1.0) - y - 1
eq2 = 2 * x + np.cos(y) - 2
# Створюємо графік
fig, ax = plt.subplots(figsize=(6, 6))

# Додаємо графік першого рівняння
ax.contour(x, y, eq1, levels=[0], colors='red')

# Додаємо графік другого рівняння
ax.contour(x, y, eq2, levels=[0], colors='blue')

# Налаштування графіка
ax.set_xlim([x_min, x_max])
ax.set_ylim([y_min, y_max])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Графік системи рівнянь')

# Додаємо стрілки на кінцях осей
ax.arrow(x_min, 0, x_max - x_min, 0, head_width=0.1, head_length=0.05, fc='black', ec='black')
ax.arrow(0, y_min, 0, y_max - y_min, head_width=0.1, head_length=0.2, fc='black', ec='black')

# Додаємо сітку
plt.grid(True)

# Показуємо графік
plt.show()

# %%
import numpy as np
from scipy import optimize
from scipy.misc import derivative
x0 = 0.50
y0 = 0.0

def f1(y):
    return np.sin(y + 1) - 1 #задаємо функції
def f2 (x):
    return 1 - 0.5 * np.cos(x) #задаємо функції
#Перевірка методу на збіжність

def iter (x,y,e):
    xn = x
    yn = y
    xn1 = f2(x)
    yn1 = f1(y)
    n = 1
    while ((abs(xn1-xn)>=e) & (abs(yn1-yn) >=e)):
        xn = xn1
        yn = yn1
        xn1 = f2(yn)
        yn1 = f1(xn)
        n += 1
    print ('Проста ітерація:')
    print ('x=', xn, '\ny=',yn,'\nКількість ітерацій = ',n)
iter(x0,y0,0.0001)
def f3(x):
    return [2 * x[0] + np.cos(x[1]) - 2, np.sin(x[0] + 1) - x[1] - 1]
s = optimize.root(f3, [0., 0.], method='hybr')
print('Перевірка', s.x)
# Out:
# Проста ітерація:
# x= 0.5000000005280978
# y= -0.0020811195668081206
# Кількість ітерацій =  4
# Перевірка [ 0.50000157 -0.0025049 ]
