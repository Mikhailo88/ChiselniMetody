# %% [markdown]
# <a href="https://colab.research.google.com/github/Mikhailo88/ChiselniMetody/blob/main/FinalProject_%D0%9E%D0%BB%D1%8C%D1%85%D0%BE%D0%B2%D0%B5%D0%BD%D0%BA%D0%BE_%D0%A4%D0%86%D0%A2_2_8_%D0%B2%D0%B0%D1%8023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/My Drive/LivyiVerhnyi.xlsx'

df = pd.read_excel(file_path)
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#       X     Y
# 0  -3.2  3.54
# 1  -3.0  3.68
# 2  -2.8  4.07
# 3  -2.6  3.94
# 4  -2.4  4.02
# 5  -2.2  3.78
# 6  -2.0  3.28
# 7  -1.8  3.38
# 8  -1.6  3.23
# 9  -1.4  3.11
# 10 -1.2  2.66
# 11 -1.0  2.73
# 12 -0.8  2.67
# 13 -0.6  2.74
# 14 -0.4  2.87
# 15 -0.2  2.26
# 16  0.0  2.19

# %%
import matplotlib.pyplot as plt

# Побудова графіка
plt.figure(figsize=(8, 4))
plt.plot(df['X'], df['Y'], marker='o', linestyle='-', color='b')

# Налаштування графіка
plt.title('Візуалізація частини кривої, що обмежує площу району')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)

# Показати графік
plt.show()

# %% [markdown]
# # 1.Сімпсон

# %%
from scipy.integrate import simpson

def Dniprovskyi_simpson(df):
    h = df['X'].iloc[1] - df['X'].iloc[0]
    s = df['Y'].iloc[0] + df['Y'].iloc[len(df)-1]
    for i in range(1, len(df)-1):
        if i % 2 == 0:
            s += 2 * df['Y'].iloc[i]
        else:
            s += 4 * df['Y'].iloc[i]
    return s * h / 3

# Результат вашої функції
result_custom = Dniprovskyi_simpson(df)

# Перевірка за допомогою вбудованої функції simpson
result_scipy = simpson(df['Y'], df['X'])

# Виведення результатів
print(f"Результат власної реалізації: {result_custom}")
print(f"Результат за допомогою simpson: {result_scipy}")
# Out:
# Результат власної реалізації: 10.25400000000001
# Результат за допомогою simpson: 10.254
# <ipython-input-15-66bffc5bfb54>:17: DeprecationWarning: You are passing x=0    -3.2
# 1    -3.0
# 2    -2.8
# 3    -2.6
# 4    -2.4
# 5    -2.2
# 6    -2.0
# 7    -1.8
# 8    -1.6
# 9    -1.4
# 10   -1.2
# 11   -1.0
# 12   -0.8
# 13   -0.6
# 14   -0.4
# 15   -0.2
# 16    0.0
# Name: X, dtype: float64 as a positional argument. Please change your invocation to use keyword arguments. From SciPy 1.14, passing these as positional arguments will result in an error.
#   result_scipy = simpson(df['Y'], df['X'])

# %%
file_path1 = '/content/drive/My Drive/PravuiVerhnyi.xlsx'

df1 = pd.read_excel(file_path1)
df1
# Out:
#       X     Y
# 0   0.2  2.83
# 1   0.4  2.92
# 2   0.6  3.22
# 3   0.8  3.30
# 4   1.0  3.57
# 5   1.2  3.80
# 6   1.4  3.72
# 7   1.6  3.78
# 8   1.8  3.69
# 9   2.0  3.64
# 10  2.2  3.77
# 11  2.4  3.74
# 12  2.6  3.62
# 13  2.8  3.66
# 14  3.0  3.46
# 15  3.2  2.82
# 16  3.4  2.67

# %%
import matplotlib.pyplot as plt

# Побудова графіка
plt.figure(figsize=(8, 4))
plt.plot(df1['X'], df1['Y'], marker='o', linestyle='-', color='b')

# Налаштування графіка
plt.title('Візуалізація частини кривої, що обмежує площу району')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)

# Показати графік
plt.show()

# %% [markdown]
# # 2.Трапеція

# %%
import pandas as pd
import numpy as np

def Dniprovskyi_trapezoid(df1):
    h = df1['X'].iloc[1] - df1['X'].iloc[0]
    s = (df1['Y'].iloc[0] + df1['Y'].iloc[-1]) / 2
    for i in range(1, len(df1)-1):
        s += df1['Y'].iloc[i]
    return s * h  # Враховуємо крок інтегрування для всієї суми

# Результат власної реалізації
result_custom = Dniprovskyi_trapezoid(df1)
print(f'Результат власної реалізації: {result_custom}')

# Перевірка за допомогою вбудованої функції numpy.trapz
result_numpy = np.trapz(df1['Y'], df1['X'])
print(f'Результат за допомогою numpy.trapz: {result_numpy}')
# Out:
# Результат власної реалізації: 11.092000000000002
# Результат за допомогою numpy.trapz: 11.091999999999999

# %%
from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/My Drive/LivuiNuzhnyi.xlsx'

df2 = pd.read_excel(file_path)
df2
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#       X     Y
# 0  -3.0  2.63
# 1  -2.8  2.56
# 2  -2.6  1.68
# 3  -2.4  1.58
# 4  -2.2  1.44
# 5  -2.0  0.74
# 6  -1.8  0.44
# 7  -1.6  0.41
# 8  -1.4  0.41
# 9  -1.2  0.24
# 10 -1.0  0.21
# 11 -0.8  0.18
# 12 -0.6  0.11
# 13 -0.4  0.23
# 14 -0.2  0.10
# 15  0.0  0.00

# %%
import matplotlib.pyplot as plt

# Побудова графіка
plt.figure(figsize=(8, 4))
plt.plot(df2['X'], df2['Y'], marker='o', linestyle='-', color='b')

# Налаштування графіка
plt.title('Візуалізація частини кривої, що обмежує площу району')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)

# Показати графік
plt.show()

# %%
import pandas as pd
import numpy as np

def Dniprovskyi_trapezoid(df2):
    h = df2['X'].iloc[1] - df2['X'].iloc[0]
    s = (df2['Y'].iloc[0] + df2['Y'].iloc[-1]) / 2
    for i in range(1, len(df2)-1):
        s += df2['Y'].iloc[i]
    return s * h  # Враховуємо крок інтегрування для всієї суми

# Результат власної реалізації
result_custom = Dniprovskyi_trapezoid(df2)
print(f'Результат власної реалізації: {result_custom}')

# Перевірка за допомогою вбудованої функції numpy.trapz
result_numpy = np.trapz(df2['Y'], df2['X'])
print(f'Результат за допомогою numpy.trapz: {result_numpy}')
# Out:
# Результат власної реалізації: 2.329000000000002
# Результат за допомогою numpy.trapz: 2.3289999999999993

# %%
from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/My Drive/PravyiNuzhnyi.xlsx'

df3 = pd.read_excel(file_path)
df3
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#       X     Y
# 0   0.0  0.16
# 1   0.2  0.29
# 2   0.4  0.49
# 3   0.6  0.55
# 4   0.8  0.54
# 5   1.0  0.60
# 6   1.2  0.63
# 7   1.4  1.44
# 8   1.6  1.83
# 9   1.8  1.78
# 10  2.0  2.19
# 11  2.2  2.02
# 12  2.4  2.11
# 13  2.6  2.15
# 14  2.8  2.23
# 15  3.0  2.35
# 16  3.2  2.41

# %%
import matplotlib.pyplot as plt

# Побудова графіка
plt.figure(figsize=(8, 4))
plt.plot(df3['X'], df3['Y'], marker='o', linestyle='-', color='b')

# Налаштування графіка
plt.title('Візуалізація частини кривої, що обмежує площу району')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)

# Показати графік
plt.show()

# %%
# Метод прямокутників

x_values = df3['X']
y_values = df3['Y']

# Обчислення інтегралу методом середніх прямокутників
integral = 0
n = len(x_values) - 1  # Кількість інтервалів

for i in range(n):
    # Ширина кожного інтервалу
    h = x_values[i+1] - x_values[i]
    # Середнє значення на інтервалі
    f_avg = (y_values[i] + y_values[i+1]) / 2
    # Площа прямокутника
    integral += h * f_avg

# Виведення тільки інтегралу, обчисленого методом середніх прямокутників
print("Метод середніх прямокутників")
print(f"integral = {integral}")

# Перевірка за допомогою вбудованої функції simpson
from scipy.integrate import simpson
result_scipy = simpson(y=df3['Y'], x=df3['X'])  # Використання ключових аргументів

# Виведення тільки інтегралу, обчисленого за допомогою методу Сімпсона
print("Перевірка методом Сімпсона")
print(f"result_scipy = {result_scipy}")
# Out:
# Метод середніх прямокутників
# integral = 4.497
# Перевірка методом Сімпсона
# result_scipy = 4.488666666666668
